# %%
from PIL import Image 
import numpy as np

# %%
with Image.open("C:\\Users\Shrey Parekh\Documents\Margin detection\images\Image_4.jpg") as im: 
    image = im.rotate(180)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Shrey Parekh\AppData\Local\Temp\ipykernel_28604\1207285740.py:1: SyntaxWarning: invalid escape sequence '\S'
#   with Image.open("C:\\Users\Shrey Parekh\Documents\Margin detection\images\Image_4.jpg") as im:

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1241x1755>

# %%
import easyocr as sc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import easyocr as sc
#
# ModuleNotFoundError: No module named 'easyocr'
